# %% [markdown]
# ## 2. Funções e gráficos

# %% [markdown]
# **Exemplo 1:** Obtendo a imagem e a representação gráfica da função $P(n)=350+50n$ com $D_f=\{2,3,4,5,6,7\}$.

# %%
# Criamos a função
def P(n):
    return 350 + n*50

# %%
# Calculamos os valores
Df = [2,3,4,5,6,7] # domínio
Imf = []           # lista vazia para a imagem

# para cada n calcula P(n) e adiciona 
for n in Df:
    Imf.append(P(n))
    print('P(',n,')=', Imf[-1])
# Out:
# P( 2 )= 450
# P( 3 )= 500
# P( 4 )= 550
# P( 5 )= 600
# P( 6 )= 650
# P( 7 )= 700

# %%
import matplotlib.pyplot as plt

# %%
# Plotamos os pontos
plt.plot(Df, Imf, 'o')
plt.grid()

# %% [markdown]
# **Exemplo 2:** Plotando o gráfico de $f(x) = x^2-7x+3$ com 21 pontos entre 10 e 10.

# %%
import numpy as np

# %%
xi = np.linspace(-10,10, 21)
f = lambda x: x**2-7*x+3
plt.plot(xi,f(xi), '.-k')
plt.grid()

# %%
print('xi:', xi[0:5])
print('yi:', f(xi[0:5]))
# Out:
# xi: [-10.  -9.  -8.  -7.  -6.]
# yi: [173. 147. 123. 101.  81.]

# %% [markdown]
# **Exemplo 2:** Plotando o gráfico de $f(d) = 1.047d^3-31.415d^2+2672.369$.

# %%
di = np.linspace(-20,40)
f = lambda d: 1.047*d**3-31.415*d**2+2672.369

plt.plot(di,f(di), '-k')
plt.grid()

# %% [markdown]
# **Exemplo 3:** Plotando mais algumas funções.

# %%
xi = np.linspace(-10,10)
f0 = lambda x: np.exp(x)*np.sin(x)
f1 = lambda x: np.cos(x)*np.log(x+10.1)
f2 = lambda x: np.arctan(x)*np.sqrt(x+10)


fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))


axs[0].plot(xi,f0(xi), '-k')
axs[0].grid()
         
axs[1].plot(xi,f1(xi), '-k')
axs[1].grid()

axs[2].plot(xi,f2(xi), '-k')
axs[2].grid()
